# %%
# Importing libraries
from youtube_transcript_api import YouTubeTranscriptApi
from pymongo import MongoClient
import requests
from clearml import Task, PipelineController, PipelineDecorator
import re

# %%
# Connecting to MongoDB

# MongoDB Configuration
MONGO_URI = "mongodb://mongoadmin:secret@localhost:27017/"
DB_NAME = "media_data_final"
COLLECTION_NAME = "raw_data_final"

# Connect to MongoDB
mongo_client = MongoClient(MONGO_URI)
db = mongo_client[DB_NAME]
collection = db[COLLECTION_NAME]

# %% [markdown]
# Creating a ClearML task to monitor the progress, and using ClearML pipelines to automate the process of fetching data from YouTube, GitHub and Websites

# %%
# ClearML Task Setup
Task.init(project_name="ETL Pipeline Main", task_name="Media Ingestion Pipeline")
# Out:
# ClearML Task: created new task id=67d9ee333e6347d9bbcd189f1f03ad2c
# 2024-12-08 18:54:29,830 - clearml.Task - INFO - Storing jupyter notebook directly as code
# ClearML results page: https://app.clear.ml/projects/56f82e0a1a2d4f18a9bd3d2f25c991b8/experiments/67d9ee333e6347d9bbcd189f1f03ad2c/output/log
# ClearML results page: https://app.clear.ml/projects/56f82e0a1a2d4f18a9bd3d2f25c991b8/experiments/67d9ee333e6347d9bbcd189f1f03ad2c/output/log
# ClearML Monitor: GPU monitoring failed getting GPU reading, switching off GPU monitoring
# ClearML Monitor: Could not detect iteration reporting, falling back to iterations as seconds-from-start

# %%
def clean_text(text):
    text = re.sub(r'<.*?>', '', text)  # Remove HTML tags
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)  # Remove special characters
    return text.strip().lower()

# %% [markdown]
# We use YoutubeTranscriptAPI to fetch the transcripts of the youtube vidoes and then we store it into mongodb. We are saving the URL of the video, the video id and the transcript returned by the API

# %%
def fetch_youtube_transcripts(url):
    video_id = url.split("v=")[1]
    transcript = YouTubeTranscriptApi.get_transcript(video_id)
    return transcript

# %%
def fetch_youtube_data():
    with open('../app/youtube_sources.txt', 'r') as file:
        # Read all lines, strip newline characters, and save to a list
        youtube_links = list(set(line.strip() for line in file))
    print(len(youtube_links))
    
    for url in youtube_links:
        transcript = fetch_youtube_transcripts(url)
        document = {
            "source": "youtube",
            "url": url,
            "video_id": url.split("v=")[1],
            "data": transcript
        }
        collection.insert_one(document)
        print("Data inserted into db for Youtube URL:", url)
    
    print("Saved complete YouTube Data into the DB")

# %% [markdown]
# The function cleans the content in github files

# %%
def clean_rst_content(text):
    # Remove directives (e.g., .. redirect-from::, .. code-block::)
    text = re.sub(r'\.\. .*::.*', '', text)
    
    # Remove list-table and code-block markers
    text = re.sub(r'\.\. (list-table|code-block)::.*', '', text)
    
    # Remove table headers and structure
    text = re.sub(r'\n\s+\* - .*', '', text)
    
    # Convert headings (e.g., ===, ---) to plain text
    text = re.sub(r'\n[=~-]{2,}\n', '\n', text)
    
    # Remove HTML-like tags (e.g., `link <url>`__)
    text = re.sub(r'`[^`]*?`__', '', text)
    
    # Remove backticks used for inline code
    text = re.sub(r'`([^`]*?)`', r'\1', text)
    
    # Remove extra newlines and trim spaces
    text = re.sub(r'\n{2,}', '\n', text).strip()
    
    # Remove leading/trailing spaces around lines
    text = "\n".join(line.strip() for line in text.splitlines())
    
    return text

# %%
def extract_and_clean(data):
    # Extract the 'content' field
    raw_content = data.get('content', '')
    
    # Clean the raw content
    cleaned_content = clean_rst_content(raw_content)
    
    return {'path': data.get('path', ''), 'content': cleaned_content}

# %% [markdown]
# Below, we scrape github repositories for any ReadME files, text files and RST files. Given the base link of the repo, we iteratively check every file in the repo and if its one of the types we need, we scrape the content and save it into MongoDB collection.

# %%
def scrape_github_repo_to_text(repo_url, access_token=None, allowed_extensions=None):
    # Extract owner and repository name from URL
    repo_name = repo_url.rstrip('/').split('/')[-1]
    owner_name = repo_url.rstrip('/').split('/')[-2]
    
    if allowed_extensions is None:
        allowed_extensions = [".txt", ".rst", ".md"]
        
    headers = {'Authorization': f'token {access_token}'} if access_token else {}
    
    # GitHub API URLs
    repo_api_url = f"https://api.github.com/repos/{owner_name}/{repo_name}"
    contents_api_url = f"{repo_api_url}/contents"
    
    # Get repository metadata
    repo_metadata = requests.get(repo_api_url, headers=headers).json()
    if 'message' in repo_metadata and 'Not Found' in repo_metadata['message']:
        print("Repository not found. Check the URL or your access token.")
        return
    
    print("Repository Metadata:")
    print("Repo metadata:", repo_metadata)
    
    # Recursive function to get all files and their content
    all_files = []
    file_names = []
    def fetch_contents(api_url, path=""):
        contents = requests.get(api_url, headers=headers).json()
        for item in contents:
                if isinstance(item, dict) and 'type' in item:
                    if item['type'] == 'file':
                        if any(item['path'].endswith(ext) for ext in allowed_extensions):
                            file_names.append(item['path'])
                            file_content = requests.get(item['download_url'], headers=headers).text
                            all_files.append({
                                "path": f"{path}/{item['name']}",
                                "content": file_content
                            })
                    elif item['type'] == 'dir':
                        fetch_contents(item['_links']['self'], path=f"{path}/{item['name']}")
                else:
                    print("Item not dict:", item)

    fetch_contents(contents_api_url)

    print(f"Fetched {len(all_files)} files from the repository.")
    return all_files

# %%
def fetch_github_data():
    access_token = "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"
    with open('../app/github_sources.txt', 'r') as file:
        # Read all lines, strip newline characters, and save to a list
        github_links = list(set(line.strip() for line in file))
    print(len(github_links))
    print(github_links)
    for link in github_links:
        repo_data = scrape_github_repo_to_text(link, access_token)
        for file in repo_data:
            cleaned_data = extract_and_clean(file)
            document = {
            "source": "github",
            "url": link,
            "path": cleaned_data.get('path', ''),
            "data": cleaned_data.get('content','')
            }
            collection.insert_one(document)
        print("Saved data into mongodb for repository:", link)
        
        
    print("Saved complete GitHub Data into the DB, number of repositories persisted:", len(github_links))

# %% [markdown]
# Helper function to query all the unique URLs that have been scraped

# %%
def query_ingested_urls():
    unique_urls = list(collection.distinct("url"))
    print("Number of ingested URLS:", len(unique_urls))
    print("Ingested URLs:")
    for entry in unique_urls:
        print(entry)

# %%
fetch_youtube_data()
# Out:
# 11
# Data inserted into db for Youtube URL: https://www.youtube.com/watch?v=96XsJ7xfsS8
# Data inserted into db for Youtube URL: https://www.youtube.com/watch?v=ERhXoIn7kr4
# Data inserted into db for Youtube URL: https://www.youtube.com/watch?v=ntJkRO_Z41I
# Data inserted into db for Youtube URL: https://www.youtube.com/watch?v=3HuV1M1NMB8
# Data inserted into db for Youtube URL: https://www.youtube.com/watch?v=Lm1ediRG5JA
# Data inserted into db for Youtube URL: https://www.youtube.com/watch?v=laWn7_cj434
# Data inserted into db for Youtube URL: https://www.youtube.com/watch?v=dxcU-_PGZdw
# Data inserted into db for Youtube URL: https://www.youtube.com/watch?v=_qQAfTmB5wc
# Data inserted into db for Youtube URL: https://www.youtube.com/watch?v=bp7MAZh4lJA
# Data inserted into db for Youtube URL: https://www.youtube.com/watch?v=8QfI5a7lTKU
# Data inserted into db for Youtube URL: https://www.youtube.com/watch?v=jkoGkAd0GYk
# Saved complete YouTube Data into the DB
# ClearML results page: https://app.clear.ml/projects/56f82e0a1a2d4f18a9bd3d2f25c991b8/experiments/3d1002c7f85a49db9897528f3444dbf0/output/log
# ClearML Monitor: GPU monitoring failed getting GPU reading, switching off GPU monitoring
# ClearML Monitor: Could not detect iteration reporting, falling back to iterations as seconds-from-start

# %%
fetch_github_data()
# Out:
# 7
# ['https://github.com/gazebosim/ros_gz', 'https://github.com/moveit/moveit_tutorials', 'https://github.com/ros-navigation/navigation2', 'https://github.com/ros2/ros2_documentation', 'https://github.com/gazebosim/docs', 'https://github.com/ros-navigation/docs.nav2.org', 'https://github.com/moveit/moveit2']
# Repository Metadata:
# Repo metadata: {'id': 143215610, 'node_id': 'MDEwOlJlcG9zaXRvcnkxNDMyMTU2MTA=', 'name': 'ros_gz', 'full_name': 'gazebosim/ros_gz', 'private': False, 'owner': {'login': 'gazebosim', 'id': 1743799, 'node_id': 'MDEyOk9yZ2FuaXphdGlvbjE3NDM3OTk=', 'avatar_url': 'https://avatars.githubusercontent.com/u/1743799?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/gazebosim', 'html_url': 'https://github.com/gazebosim', 'followers_url': 'https://api.github.com/users/gazebosim/followers', 'following_url': 'https://api.github.com/users/gazebosim/following{/other_user}', 'gists_url': 'https://api.github.com/users/gazebosim/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/gazebosim/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/gazebosim/subscriptions', 'organizations_url': 'https://api.github.com/users/gazebosim/orgs', 'repos_url': 'https://api.github.com/users/gazebosim/repos', 'events_url': 'https://api.github.com/users/gazebosim/events{/privacy}', 'received_events_url': 'https://api.github.com/users/gazebosim/received_events', 'type': 'Organization', 'user_view_type': 'public', 'site_admin': False}, 'html_url': 'https://github.com/gazebosim/ros_gz', 'description': 'Integration between ROS (1 and 2) and Gazebo simulation', 'fork': False, 'url': 'https://api.github.com/repos/gazebosim/ros_gz', 'forks_url': 'https://api.github.com/repos/gazebosim/ros_gz/forks', 'keys_url': 'https://api.github.com/repos/gazebosim/ros_gz/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/gazebosim/ros_gz/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/gazebosim/ros_gz/teams', 'hooks_url': 'https://api.github.com/repos/gazebosim/ros_gz/hooks', 'issue_events_url': 'https://api.github.com/repos/gazebosim/ros_gz/issues/events{/number}', 'events_url': 'https://api.github.com/repos/gazebosim/ros_gz/events', 'assignees_url': 'https://api.github.com/repos/gazebosim/ros_gz/assignees{/user}', 'branches_url': 'https://api.github.com/repos/gazebosim/ros_gz/branches{/branch}', 'tags_url': 'https://api.github.com/repos/gazebosim/ros_gz/tags', 'blobs_url': 'https://api.github.com/repos/gazebosim/ros_gz/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/gazebosim/ros_gz/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/gazebosim/ros_gz/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/gazebosim/ros_gz/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/gazebosim/ros_gz/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/gazebosim/ros_gz/languages', 'stargazers_url': 'https://api.github.com/repos/gazebosim/ros_gz/stargazers', 'contributors_url': 'https://api.github.com/repos/gazebosim/ros_gz/contributors', 'subscribers_url': 'https://api.github.com/repos/gazebosim/ros_gz/subscribers', 'subscription_url': 'https://api.github.com/repos/gazebosim/ros_gz/subscription', 'commits_url': 'https://api.github.com/repos/gazebosim/ros_gz/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/gazebosim/ros_gz/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/gazebosim/ros_gz/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/gazebosim/ros_gz/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/gazebosim/ros_gz/contents/{+path}', 'compare_url': 'https://api.github.com/repos/gazebosim/ros_gz/compare/{base}...{head}', 'merges_url': 'https://api.github.com/repos/gazebosim/ros_gz/merges', 'archive_url': 'https://api.github.com/repos/gazebosim/ros_gz/{archive_format}{/ref}', 'downloads_url': 'https://api.github.com/repos/gazebosim/ros_gz/downloads', 'issues_url': 'https://api.github.com/repos/gazebosim/ros_gz/issues{/number}', 'pulls_url': 'https://api.github.com/repos/gazebosim/ros_gz/pulls{/number}', 'milestones_url': 'https://api.github.com/repos/gazebosim/ros_gz/milestones{/number}', 'notifications_url': 'https://api.github.com/repos/gazebosim/ros_gz/notifications{?since,a ...
# Fetched 26 files from the repository.
# Saved data into mongodb for repository: https://github.com/gazebosim/ros_gz
# Repository Metadata:
# Repo metadata: {'id': 66317561, 'node_id': 'MDEwOlJlcG9zaXRvcnk2NjMxNzU2MQ==', 'name': 'moveit_tutorials', 'full_name': 'moveit/moveit_tutorials', 'private': False, 'owner': {'login': 'moveit', 'id': 4408844, 'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ0MDg4NDQ=', 'avatar_url': 'https://avatars.githubusercontent.com/u/4408844?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/moveit', 'html_url': 'https://github.com/moveit', 'followers_url': 'https://api.github.com/users/moveit/followers', 'following_url': 'https://api.github.com/users/moveit/following{/other_user}', 'gists_url': 'https://api.github.com/users/moveit/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/moveit/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/moveit/subscriptions', 'organizations_url': 'https://api.github.com/users/moveit/orgs', 'repos_url': 'https://api.github.com/users/moveit/repos', 'events_url': 'https://api.github.com/users/moveit/events{/privacy}', 'received_events_url': 'https://api.github.com/users/moveit/received_events', 'type': 'Organization', 'user_view_type': 'public', 'site_admin': False}, 'html_url': 'https://github.com/moveit/moveit_tutorials', 'description': 'A sphinx-based centralized documentation repo for MoveIt', 'fork': False, 'url': 'https://api.github.com/repos/moveit/moveit_tutorials', 'forks_url': 'https://api.github.com/repos/moveit/moveit_tutorials/forks', 'keys_url': 'https://api.github.com/repos/moveit/moveit_tutorials/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/moveit/moveit_tutorials/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/moveit/moveit_tutorials/teams', 'hooks_url': 'https://api.github.com/repos/moveit/moveit_tutorials/hooks', 'issue_events_url': 'https://api.github.com/repos/moveit/moveit_tutorials/issues/events{/number}', 'events_url': 'https://api.github.com/repos/moveit/moveit_tutorials/events', 'assignees_url': 'https://api.github.com/repos/moveit/moveit_tutorials/assignees{/user}', 'branches_url': 'https://api.github.com/repos/moveit/moveit_tutorials/branches{/branch}', 'tags_url': 'https://api.github.com/repos/moveit/moveit_tutorials/tags', 'blobs_url': 'https://api.github.com/repos/moveit/moveit_tutorials/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/moveit/moveit_tutorials/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/moveit/moveit_tutorials/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/moveit/moveit_tutorials/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/moveit/moveit_tutorials/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/moveit/moveit_tutorials/languages', 'stargazers_url': 'https://api.github.com/repos/moveit/moveit_tutorials/stargazers', 'contributors_url': 'https://api.github.com/repos/moveit/moveit_tutorials/contributors', 'subscribers_url': 'https://api.github.com/repos/moveit/moveit_tutorials/subscribers', 'subscription_url': 'https://api.github.com/repos/moveit/moveit_tutorials/subscription', 'commits_url': 'https://api.github.com/repos/moveit/moveit_tutorials/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/moveit/moveit_tutorials/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/moveit/moveit_tutorials/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/moveit/moveit_tutorials/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/moveit/moveit_tutorials/contents/{+path}', 'compare_url': 'https://api.github.com/repos/moveit/moveit_tutorials/compare/{base}...{head}', 'merges_url': 'https://api.github.com/repos/moveit/moveit_tutorials/merges', 'archive_url': 'https://api.github.com/repos/moveit/moveit_tutorials/{archive_format}{/ref}', 'downloads_url': 'https://api.github.com/repos/moveit/moveit_tutorials/downloads', 'issues_url': 'https://api.github.com/repos/moveit/moveit_tutorials/issues{/number}', 'pulls_url': 'https://api.github.com/repos/moveit ...
# Fetched 78 files from the repository.
# Saved data into mongodb for repository: https://github.com/moveit/moveit_tutorials
# Repository Metadata:
# Repo metadata: {'id': 135363400, 'node_id': 'MDEwOlJlcG9zaXRvcnkxMzUzNjM0MDA=', 'name': 'navigation2', 'full_name': 'ros-navigation/navigation2', 'private': False, 'owner': {'login': 'ros-navigation', 'id': 150733807, 'node_id': 'O_kgDOCPwD7w', 'avatar_url': 'https://avatars.githubusercontent.com/u/150733807?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/ros-navigation', 'html_url': 'https://github.com/ros-navigation', 'followers_url': 'https://api.github.com/users/ros-navigation/followers', 'following_url': 'https://api.github.com/users/ros-navigation/following{/other_user}', 'gists_url': 'https://api.github.com/users/ros-navigation/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/ros-navigation/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/ros-navigation/subscriptions', 'organizations_url': 'https://api.github.com/users/ros-navigation/orgs', 'repos_url': 'https://api.github.com/users/ros-navigation/repos', 'events_url': 'https://api.github.com/users/ros-navigation/events{/privacy}', 'received_events_url': 'https://api.github.com/users/ros-navigation/received_events', 'type': 'Organization', 'user_view_type': 'public', 'site_admin': False}, 'html_url': 'https://github.com/ros-navigation/navigation2', 'description': 'ROS 2 Navigation Framework and System', 'fork': False, 'url': 'https://api.github.com/repos/ros-navigation/navigation2', 'forks_url': 'https://api.github.com/repos/ros-navigation/navigation2/forks', 'keys_url': 'https://api.github.com/repos/ros-navigation/navigation2/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/ros-navigation/navigation2/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/ros-navigation/navigation2/teams', 'hooks_url': 'https://api.github.com/repos/ros-navigation/navigation2/hooks', 'issue_events_url': 'https://api.github.com/repos/ros-navigation/navigation2/issues/events{/number}', 'events_url': 'https://api.github.com/repos/ros-navigation/navigation2/events', 'assignees_url': 'https://api.github.com/repos/ros-navigation/navigation2/assignees{/user}', 'branches_url': 'https://api.github.com/repos/ros-navigation/navigation2/branches{/branch}', 'tags_url': 'https://api.github.com/repos/ros-navigation/navigation2/tags', 'blobs_url': 'https://api.github.com/repos/ros-navigation/navigation2/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/ros-navigation/navigation2/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/ros-navigation/navigation2/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/ros-navigation/navigation2/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/ros-navigation/navigation2/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/ros-navigation/navigation2/languages', 'stargazers_url': 'https://api.github.com/repos/ros-navigation/navigation2/stargazers', 'contributors_url': 'https://api.github.com/repos/ros-navigation/navigation2/contributors', 'subscribers_url': 'https://api.github.com/repos/ros-navigation/navigation2/subscribers', 'subscription_url': 'https://api.github.com/repos/ros-navigation/navigation2/subscription', 'commits_url': 'https://api.github.com/repos/ros-navigation/navigation2/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/ros-navigation/navigation2/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/ros-navigation/navigation2/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/ros-navigation/navigation2/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/ros-navigation/navigation2/contents/{+path}', 'compare_url': 'https://api.github.com/repos/ros-navigation/navigation2/compare/{base}...{head}', 'merges_url': 'https://api.github.com/repos/ros-navigation/navigation2/merges', 'archive_url': 'https://api.github.com/repos/ros-navigation/navigation2/{archive_format}{/ref}', 'downloads_url': 'https://api.github.com/repos/ros-navigation/naviga ...
# Fetched 177 files from the repository.
# Saved data into mongodb for repository: https://github.com/ros-navigation/navigation2
# Repository Metadata:
# Repo metadata: {'id': 148210342, 'node_id': 'MDEwOlJlcG9zaXRvcnkxNDgyMTAzNDI=', 'name': 'ros2_documentation', 'full_name': 'ros2/ros2_documentation', 'private': False, 'owner': {'login': 'ros2', 'id': 3979232, 'node_id': 'MDEyOk9yZ2FuaXphdGlvbjM5NzkyMzI=', 'avatar_url': 'https://avatars.githubusercontent.com/u/3979232?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/ros2', 'html_url': 'https://github.com/ros2', 'followers_url': 'https://api.github.com/users/ros2/followers', 'following_url': 'https://api.github.com/users/ros2/following{/other_user}', 'gists_url': 'https://api.github.com/users/ros2/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/ros2/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/ros2/subscriptions', 'organizations_url': 'https://api.github.com/users/ros2/orgs', 'repos_url': 'https://api.github.com/users/ros2/repos', 'events_url': 'https://api.github.com/users/ros2/events{/privacy}', 'received_events_url': 'https://api.github.com/users/ros2/received_events', 'type': 'Organization', 'user_view_type': 'public', 'site_admin': False}, 'html_url': 'https://github.com/ros2/ros2_documentation', 'description': 'ROS 2 docs repository', 'fork': False, 'url': 'https://api.github.com/repos/ros2/ros2_documentation', 'forks_url': 'https://api.github.com/repos/ros2/ros2_documentation/forks', 'keys_url': 'https://api.github.com/repos/ros2/ros2_documentation/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/ros2/ros2_documentation/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/ros2/ros2_documentation/teams', 'hooks_url': 'https://api.github.com/repos/ros2/ros2_documentation/hooks', 'issue_events_url': 'https://api.github.com/repos/ros2/ros2_documentation/issues/events{/number}', 'events_url': 'https://api.github.com/repos/ros2/ros2_documentation/events', 'assignees_url': 'https://api.github.com/repos/ros2/ros2_documentation/assignees{/user}', 'branches_url': 'https://api.github.com/repos/ros2/ros2_documentation/branches{/branch}', 'tags_url': 'https://api.github.com/repos/ros2/ros2_documentation/tags', 'blobs_url': 'https://api.github.com/repos/ros2/ros2_documentation/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/ros2/ros2_documentation/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/ros2/ros2_documentation/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/ros2/ros2_documentation/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/ros2/ros2_documentation/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/ros2/ros2_documentation/languages', 'stargazers_url': 'https://api.github.com/repos/ros2/ros2_documentation/stargazers', 'contributors_url': 'https://api.github.com/repos/ros2/ros2_documentation/contributors', 'subscribers_url': 'https://api.github.com/repos/ros2/ros2_documentation/subscribers', 'subscription_url': 'https://api.github.com/repos/ros2/ros2_documentation/subscription', 'commits_url': 'https://api.github.com/repos/ros2/ros2_documentation/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/ros2/ros2_documentation/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/ros2/ros2_documentation/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/ros2/ros2_documentation/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/ros2/ros2_documentation/contents/{+path}', 'compare_url': 'https://api.github.com/repos/ros2/ros2_documentation/compare/{base}...{head}', 'merges_url': 'https://api.github.com/repos/ros2/ros2_documentation/merges', 'archive_url': 'https://api.github.com/repos/ros2/ros2_documentation/{archive_format}{/ref}', 'downloads_url': 'https://api.github.com/repos/ros2/ros2_documentation/downloads', 'issues_url': 'https://api.github.com/repos/ros2/ros2_documentation/issues{/number}', 'pulls_url': 'https://api.github.com/repos/ros2/ros2_documentation/pulls{/number}', 'milestones_url': 'ht ...
# Fetched 278 files from the repository.
# Saved data into mongodb for repository: https://github.com/ros2/ros2_documentation
# Repository Metadata:
# Repo metadata: {'id': 255865180, 'node_id': 'MDEwOlJlcG9zaXRvcnkyNTU4NjUxODA=', 'name': 'docs', 'full_name': 'gazebosim/docs', 'private': False, 'owner': {'login': 'gazebosim', 'id': 1743799, 'node_id': 'MDEyOk9yZ2FuaXphdGlvbjE3NDM3OTk=', 'avatar_url': 'https://avatars.githubusercontent.com/u/1743799?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/gazebosim', 'html_url': 'https://github.com/gazebosim', 'followers_url': 'https://api.github.com/users/gazebosim/followers', 'following_url': 'https://api.github.com/users/gazebosim/following{/other_user}', 'gists_url': 'https://api.github.com/users/gazebosim/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/gazebosim/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/gazebosim/subscriptions', 'organizations_url': 'https://api.github.com/users/gazebosim/orgs', 'repos_url': 'https://api.github.com/users/gazebosim/repos', 'events_url': 'https://api.github.com/users/gazebosim/events{/privacy}', 'received_events_url': 'https://api.github.com/users/gazebosim/received_events', 'type': 'Organization', 'user_view_type': 'public', 'site_admin': False}, 'html_url': 'https://github.com/gazebosim/docs', 'description': 'High-level Gazebo documentation that gets published to https://gazebosim.org/docs/', 'fork': False, 'url': 'https://api.github.com/repos/gazebosim/docs', 'forks_url': 'https://api.github.com/repos/gazebosim/docs/forks', 'keys_url': 'https://api.github.com/repos/gazebosim/docs/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/gazebosim/docs/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/gazebosim/docs/teams', 'hooks_url': 'https://api.github.com/repos/gazebosim/docs/hooks', 'issue_events_url': 'https://api.github.com/repos/gazebosim/docs/issues/events{/number}', 'events_url': 'https://api.github.com/repos/gazebosim/docs/events', 'assignees_url': 'https://api.github.com/repos/gazebosim/docs/assignees{/user}', 'branches_url': 'https://api.github.com/repos/gazebosim/docs/branches{/branch}', 'tags_url': 'https://api.github.com/repos/gazebosim/docs/tags', 'blobs_url': 'https://api.github.com/repos/gazebosim/docs/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/gazebosim/docs/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/gazebosim/docs/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/gazebosim/docs/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/gazebosim/docs/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/gazebosim/docs/languages', 'stargazers_url': 'https://api.github.com/repos/gazebosim/docs/stargazers', 'contributors_url': 'https://api.github.com/repos/gazebosim/docs/contributors', 'subscribers_url': 'https://api.github.com/repos/gazebosim/docs/subscribers', 'subscription_url': 'https://api.github.com/repos/gazebosim/docs/subscription', 'commits_url': 'https://api.github.com/repos/gazebosim/docs/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/gazebosim/docs/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/gazebosim/docs/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/gazebosim/docs/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/gazebosim/docs/contents/{+path}', 'compare_url': 'https://api.github.com/repos/gazebosim/docs/compare/{base}...{head}', 'merges_url': 'https://api.github.com/repos/gazebosim/docs/merges', 'archive_url': 'https://api.github.com/repos/gazebosim/docs/{archive_format}{/ref}', 'downloads_url': 'https://api.github.com/repos/gazebosim/docs/downloads', 'issues_url': 'https://api.github.com/repos/gazebosim/docs/issues{/number}', 'pulls_url': 'https://api.github.com/repos/gazebosim/docs/pulls{/number}', 'milestones_url': 'https://api.github.com/repos/gazebosim/docs/milestones{/number}', 'notifications_url': 'https://api.github.com/repos/gazebosim/docs/notifications{?since,all,participating}', 'labels_url': 'https://api. ...
# Fetched 247 files from the repository.
# Saved data into mongodb for repository: https://github.com/gazebosim/docs
# Repository Metadata:
# Repo metadata: {'id': 240847415, 'node_id': 'MDEwOlJlcG9zaXRvcnkyNDA4NDc0MTU=', 'name': 'docs.nav2.org', 'full_name': 'ros-navigation/docs.nav2.org', 'private': False, 'owner': {'login': 'ros-navigation', 'id': 150733807, 'node_id': 'O_kgDOCPwD7w', 'avatar_url': 'https://avatars.githubusercontent.com/u/150733807?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/ros-navigation', 'html_url': 'https://github.com/ros-navigation', 'followers_url': 'https://api.github.com/users/ros-navigation/followers', 'following_url': 'https://api.github.com/users/ros-navigation/following{/other_user}', 'gists_url': 'https://api.github.com/users/ros-navigation/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/ros-navigation/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/ros-navigation/subscriptions', 'organizations_url': 'https://api.github.com/users/ros-navigation/orgs', 'repos_url': 'https://api.github.com/users/ros-navigation/repos', 'events_url': 'https://api.github.com/users/ros-navigation/events{/privacy}', 'received_events_url': 'https://api.github.com/users/ros-navigation/received_events', 'type': 'Organization', 'user_view_type': 'public', 'site_admin': False}, 'html_url': 'https://github.com/ros-navigation/docs.nav2.org', 'description': 'https://docs.nav2.org/', 'fork': False, 'url': 'https://api.github.com/repos/ros-navigation/docs.nav2.org', 'forks_url': 'https://api.github.com/repos/ros-navigation/docs.nav2.org/forks', 'keys_url': 'https://api.github.com/repos/ros-navigation/docs.nav2.org/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/ros-navigation/docs.nav2.org/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/ros-navigation/docs.nav2.org/teams', 'hooks_url': 'https://api.github.com/repos/ros-navigation/docs.nav2.org/hooks', 'issue_events_url': 'https://api.github.com/repos/ros-navigation/docs.nav2.org/issues/events{/number}', 'events_url': 'https://api.github.com/repos/ros-navigation/docs.nav2.org/events', 'assignees_url': 'https://api.github.com/repos/ros-navigation/docs.nav2.org/assignees{/user}', 'branches_url': 'https://api.github.com/repos/ros-navigation/docs.nav2.org/branches{/branch}', 'tags_url': 'https://api.github.com/repos/ros-navigation/docs.nav2.org/tags', 'blobs_url': 'https://api.github.com/repos/ros-navigation/docs.nav2.org/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/ros-navigation/docs.nav2.org/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/ros-navigation/docs.nav2.org/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/ros-navigation/docs.nav2.org/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/ros-navigation/docs.nav2.org/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/ros-navigation/docs.nav2.org/languages', 'stargazers_url': 'https://api.github.com/repos/ros-navigation/docs.nav2.org/stargazers', 'contributors_url': 'https://api.github.com/repos/ros-navigation/docs.nav2.org/contributors', 'subscribers_url': 'https://api.github.com/repos/ros-navigation/docs.nav2.org/subscribers', 'subscription_url': 'https://api.github.com/repos/ros-navigation/docs.nav2.org/subscription', 'commits_url': 'https://api.github.com/repos/ros-navigation/docs.nav2.org/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/ros-navigation/docs.nav2.org/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/ros-navigation/docs.nav2.org/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/ros-navigation/docs.nav2.org/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/ros-navigation/docs.nav2.org/contents/{+path}', 'compare_url': 'https://api.github.com/repos/ros-navigation/docs.nav2.org/compare/{base}...{head}', 'merges_url': 'https://api.github.com/repos/ros-navigation/docs.nav2.org/merges', 'archive_url': 'https://api.github.com/repos/ros-navigation/docs.nav2.org/{archive_format}{/ref}', 'downloads_url': 'h ...
# Fetched 212 files from the repository.
# Saved data into mongodb for repository: https://github.com/ros-navigation/docs.nav2.org
# Repository Metadata:
# Repo metadata: {'id': 170893393, 'node_id': 'MDEwOlJlcG9zaXRvcnkxNzA4OTMzOTM=', 'name': 'moveit2', 'full_name': 'moveit/moveit2', 'private': False, 'owner': {'login': 'moveit', 'id': 4408844, 'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ0MDg4NDQ=', 'avatar_url': 'https://avatars.githubusercontent.com/u/4408844?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/moveit', 'html_url': 'https://github.com/moveit', 'followers_url': 'https://api.github.com/users/moveit/followers', 'following_url': 'https://api.github.com/users/moveit/following{/other_user}', 'gists_url': 'https://api.github.com/users/moveit/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/moveit/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/moveit/subscriptions', 'organizations_url': 'https://api.github.com/users/moveit/orgs', 'repos_url': 'https://api.github.com/users/moveit/repos', 'events_url': 'https://api.github.com/users/moveit/events{/privacy}', 'received_events_url': 'https://api.github.com/users/moveit/received_events', 'type': 'Organization', 'user_view_type': 'public', 'site_admin': False}, 'html_url': 'https://github.com/moveit/moveit2', 'description': ':robot: MoveIt for ROS 2', 'fork': False, 'url': 'https://api.github.com/repos/moveit/moveit2', 'forks_url': 'https://api.github.com/repos/moveit/moveit2/forks', 'keys_url': 'https://api.github.com/repos/moveit/moveit2/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/moveit/moveit2/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/moveit/moveit2/teams', 'hooks_url': 'https://api.github.com/repos/moveit/moveit2/hooks', 'issue_events_url': 'https://api.github.com/repos/moveit/moveit2/issues/events{/number}', 'events_url': 'https://api.github.com/repos/moveit/moveit2/events', 'assignees_url': 'https://api.github.com/repos/moveit/moveit2/assignees{/user}', 'branches_url': 'https://api.github.com/repos/moveit/moveit2/branches{/branch}', 'tags_url': 'https://api.github.com/repos/moveit/moveit2/tags', 'blobs_url': 'https://api.github.com/repos/moveit/moveit2/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/moveit/moveit2/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/moveit/moveit2/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/moveit/moveit2/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/moveit/moveit2/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/moveit/moveit2/languages', 'stargazers_url': 'https://api.github.com/repos/moveit/moveit2/stargazers', 'contributors_url': 'https://api.github.com/repos/moveit/moveit2/contributors', 'subscribers_url': 'https://api.github.com/repos/moveit/moveit2/subscribers', 'subscription_url': 'https://api.github.com/repos/moveit/moveit2/subscription', 'commits_url': 'https://api.github.com/repos/moveit/moveit2/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/moveit/moveit2/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/moveit/moveit2/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/moveit/moveit2/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/moveit/moveit2/contents/{+path}', 'compare_url': 'https://api.github.com/repos/moveit/moveit2/compare/{base}...{head}', 'merges_url': 'https://api.github.com/repos/moveit/moveit2/merges', 'archive_url': 'https://api.github.com/repos/moveit/moveit2/{archive_format}{/ref}', 'downloads_url': 'https://api.github.com/repos/moveit/moveit2/downloads', 'issues_url': 'https://api.github.com/repos/moveit/moveit2/issues{/number}', 'pulls_url': 'https://api.github.com/repos/moveit/moveit2/pulls{/number}', 'milestones_url': 'https://api.github.com/repos/moveit/moveit2/milestones{/number}', 'notifications_url': 'https://api.github.com/repos/moveit/moveit2/notifications{?since,all,participating}', 'labels_url': 'https://api.github.com/repos/moveit/moveit2/labels{/name}', 'releases_url': 'https://api.github.com/rep ...
# Fetched 200 files from the repository.
# Saved data into mongodb for repository: https://github.com/moveit/moveit2
# Saved complete GitHub Data into the DB, number of repositories persisted: 7

# %%
query_ingested_urls()
# Out:
# Number of ingested URLS: 18
# Ingested URLs:
# https://github.com/gazebosim/docs
# https://github.com/gazebosim/ros_gz
# https://github.com/moveit/moveit2
# https://github.com/moveit/moveit_tutorials
# https://github.com/ros-navigation/docs.nav2.org
# https://github.com/ros-navigation/navigation2
# https://github.com/ros2/ros2_documentation
# https://www.youtube.com/watch?v=3HuV1M1NMB8
# https://www.youtube.com/watch?v=8QfI5a7lTKU
# https://www.youtube.com/watch?v=96XsJ7xfsS8
# https://www.youtube.com/watch?v=ERhXoIn7kr4
# https://www.youtube.com/watch?v=Lm1ediRG5JA
# https://www.youtube.com/watch?v=_qQAfTmB5wc
# https://www.youtube.com/watch?v=bp7MAZh4lJA
# https://www.youtube.com/watch?v=dxcU-_PGZdw
# https://www.youtube.com/watch?v=jkoGkAd0GYk
# https://www.youtube.com/watch?v=laWn7_cj434
# https://www.youtube.com/watch?v=ntJkRO_Z41I

# %% [markdown]
# Below, we use BeautifulSoup to scrape and parse the ROS2 and Gazebo documentation from the web pages

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin


def scrape_gazebo_docs(base_url, max_pages=10):
    visited_urls = set()
    to_visit = []
    scraped_data = []

    def fetch_navigation_links(url):
        """Fetch links from the navigation menu."""
        print(f"Fetching navigation links from: {url}")
        response = requests.get(url)
        if response.status_code != 200:
            print(f"Failed to fetch {url}")
            return []

        soup = BeautifulSoup(response.text, 'html.parser')

        # Find the navigation menu links
        navigation_div = soup.find('div', class_='bd-toc-item')
        if not navigation_div:
            print("Navigation menu not found.")
            return []

        # Extract all anchor links within the navigation menu
        links = [
            urljoin(base_url, a['href'])
            for a in navigation_div.find_all('a', href=True)
            if a['href'] and not a['href'].startswith('#')  # Exclude fragment identifiers
        ]

        return links

    def fetch_page_content(url):
        """Fetch and parse the content of a single page."""
        print(f"Fetching page content from: {url}")
        response = requests.get(url)
        if response.status_code != 200:
            print(f"Failed to fetch {url}")
            return None

        soup = BeautifulSoup(response.text, 'html.parser')
        title = soup.find('title').text.strip() if soup.find('title') else "No title"

        # Extract main content from <div role="main">
        content_div = soup.find('article', class_='bd-article')
        if content_div:
            # Extract all text while stripping HTML tags
            content_text = content_div.get_text(separator="\n", strip=True)
        else:
            content_text = "No content available."

        return {"url": url, "title": title, "content": content_text}

    # Start by fetching navigation links from the base URL
    to_visit.extend(fetch_navigation_links(base_url))

    for url in to_visit[:max_pages]:
        if url in visited_urls:
            continue

        page_data = fetch_page_content(url)
        if page_data:
            scraped_data.append(page_data)
            visited_urls.add(url)

    return scraped_data

def scrape_ros_docs(base_url, max_pages=10):
    visited_urls = set()
    to_visit = []
    scraped_data = []

    def fetch_navigation_links(url):
        """Fetch links from the navigation menu."""
        print(f"Fetching navigation links from: {url}")
        response = requests.get(url)
        if response.status_code != 200:
            print(f"Failed to fetch {url}")
            return []

        soup = BeautifulSoup(response.text, 'html.parser')

        # Find the navigation menu links
        navigation_div = soup.find('div', class_='wy-menu wy-menu-vertical')
        if not navigation_div:
            print("Navigation menu not found.")
            return []

        # Extract all anchor links within the navigation menu
        links = [
            urljoin(base_url, a['href'])
            for a in navigation_div.find_all('a', href=True)
            if a['href'] and not a['href'].startswith('#')  # Exclude fragment identifiers
        ]
        return links

    def fetch_page_content(url):
        """Fetch and parse the content of a single page."""
        print(f"Fetching page content from: {url}")
        response = requests.get(url)
        if response.status_code != 200:
            print(f"Failed to fetch {url}")
            return None

        soup = BeautifulSoup(response.text, 'html.parser')
        title = soup.find('title').text.strip() if soup.find('title') else "No title"

        # Extract main content from <div role="main">
        content_div = soup.find('div', {'role': 'main'})
        if content_div:
            # Extract all text while stripping HTML tags
            content_text = content_div.get_text(separator="\n", strip=True)
        else:
            content_text = "No content available."

        return {"url": url, "title": title, "content": content_text}

    # Start by fetching navigation links from the base URL
    to_visit.extend(fetch_navigation_links(base_url))

    for url in to_visit[:max_pages]:
        if url in visited_urls:
            continue

        page_data = fetch_page_content(url)
        if page_data:
            scraped_data.append(page_data)
            visited_urls.add(url)

    return scraped_data


# Usage
base_urls = ["https://docs.ros.org/en/galactic/index.html", "https://docs.nav2.org/getting_started/index.html", "https://docs.ros.org/en/kinetic/api/moveit_tutorials/html/index.html"]
scraped_docs = []
for base_url in base_urls:
    # scraped_docs = scrape_ros_docs(base_url, max_pages=-1)
    scraped_docs.extend(scrape_ros_docs(base_url, max_pages=-1))

gazebo_base_url = "https://gazebosim.org/docs/latest/getstarted/"
gazebo_docs = scrape_gazebo_docs(gazebo_base_url, max_pages=-1)
scraped_docs.extend(gazebo_docs)

# Print scraped data
# for doc in scraped_docs:
#     print(f"Title: {doc['title']}")
#     print(f"URL: {doc['url']}")
#     print(f"Content Snippet: {doc['content'][:1000]}...")  # Print first 1000 characters of content text
#     print()
# Out:
# Fetching navigation links from: https://docs.ros.org/en/galactic/index.html
# Fetching page content from: https://docs.ros.org/en/galactic/Installation.html
# Fetching page content from: https://docs.ros.org/en/galactic/Installation/Ubuntu-Install-Debians.html
# Fetching page content from: https://docs.ros.org/en/galactic/Installation/Windows-Install-Binary.html
# Fetching page content from: https://docs.ros.org/en/galactic/Installation/RHEL-Install-RPMs.html
# Fetching page content from: https://docs.ros.org/en/galactic/Installation/Alternatives.html
# Fetching page content from: https://docs.ros.org/en/galactic/Installation/Alternatives/Ubuntu-Development-Setup.html
# Fetching page content from: https://docs.ros.org/en/galactic/Installation/Alternatives/Ubuntu-Install-Binary.html
# Fetching page content from: https://docs.ros.org/en/galactic/Installation/Alternatives/Windows-Development-Setup.html
# Fetching page content from: https://docs.ros.org/en/galactic/Installation/Alternatives/RHEL-Development-Setup.html
# Fetching page content from: https://docs.ros.org/en/galactic/Installation/Alternatives/RHEL-Install-Binary.html
# Fetching page content from: https://docs.ros.org/en/galactic/Installation/Alternatives/macOS-Development-Setup.html
# Fetching page content from: https://docs.ros.org/en/galactic/Installation/Alternatives/Fedora-Development-Setup.html
# Fetching page content from: https://docs.ros.org/en/galactic/Installation/Alternatives/Latest-Development-Setup.html
# Fetching page content from: https://docs.ros.org/en/galactic/Installation/Maintaining-a-Source-Checkout.html
# Fetching page content from: https://docs.ros.org/en/galactic/Installation/Testing.html
# Fetching page content from: https://docs.ros.org/en/galactic/Installation/DDS-Implementations.html
# Fetching page content from: https://docs.ros.org/en/galactic/Installation/DDS-Implementations/Install-Connext-Security-Plugins.html
# Fetching page content from: https://docs.ros.org/en/galactic/Installation/DDS-Implementations/Install-Connext-University-Eval.html
# Fetching page content from: https://docs.ros.org/en/galactic/Installation/DDS-Implementations/Working-with-Eclipse-CycloneDDS.html
# Fetching page content from: https://docs.ros.org/en/galactic/Installation/DDS-Implementations/Working-with-GurumNetworks-GurumDDS.html
# Fetching page content from: https://docs.ros.org/en/galactic/Installation/DDS-Implementations/Working-with-eProsima-Fast-DDS.html
# Fetching page content from: https://docs.ros.org/en/galactic/Releases.html
# Fetching page content from: https://docs.ros.org/en/galactic/Releases/Release-Humble-Hawksbill.html
# Fetching page content from: https://docs.ros.org/en/galactic/Releases/Humble-Hawksbill-Complete-Changelog.html

# %%
len(scraped_docs)
# Out:
# 1343

# %%
for doc in scraped_docs:
    document = {
        "source": "web",
        "url": doc.get('url', ''),
        "title": doc.get('title', ''),
        "content": doc.get('content', '')
    }
    collection.insert_one(document)
    print(f"Saved data into MongoDB for URL: {doc.get('url', '')}")
# Out:
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Installation.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Installation/Ubuntu-Install-Debians.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Installation/Windows-Install-Binary.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Installation/RHEL-Install-RPMs.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Installation/Alternatives.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Installation/Alternatives/Ubuntu-Development-Setup.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Installation/Alternatives/Ubuntu-Install-Binary.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Installation/Alternatives/Windows-Development-Setup.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Installation/Alternatives/RHEL-Development-Setup.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Installation/Alternatives/RHEL-Install-Binary.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Installation/Alternatives/macOS-Development-Setup.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Installation/Alternatives/Fedora-Development-Setup.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Installation/Alternatives/Latest-Development-Setup.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Installation/Maintaining-a-Source-Checkout.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Installation/Testing.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Installation/DDS-Implementations.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Installation/DDS-Implementations/Install-Connext-Security-Plugins.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Installation/DDS-Implementations/Install-Connext-University-Eval.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Installation/DDS-Implementations/Working-with-Eclipse-CycloneDDS.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Installation/DDS-Implementations/Working-with-GurumNetworks-GurumDDS.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Installation/DDS-Implementations/Working-with-eProsima-Fast-DDS.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Releases.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Releases/Release-Humble-Hawksbill.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Releases/Humble-Hawksbill-Complete-Changelog.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Releases/Release-Foxy-Fitzroy.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Releases/Release-Rolling-Ridley.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Releases/Development.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Releases/Release-Iron-Irwini.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Releases/End-of-Life.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Releases/Release-Galactic-Geochelone.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Releases/Galactic-Geochelone-Complete-Changelog.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Releases/Release-Eloquent-Elusor.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Releases/Release-Dashing-Diademata.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Releases/Release-Crystal-Clemmys.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Releases/Release-Bouncy-Bolson.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Releases/Release-Ardent-Apalone.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Releases/Beta3-Overview.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Releases/Beta2-Overview.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Releases/Beta1-Overview.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Releases/Alpha-Overview.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Releases/Release-Process.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Beginner-CLI-Tools.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Beginner-CLI-Tools/Configuring-ROS2-Environment.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Beginner-CLI-Tools/Introducing-Turtlesim/Introducing-Turtlesim.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Beginner-CLI-Tools/Understanding-ROS2-Nodes/Understanding-ROS2-Nodes.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Beginner-CLI-Tools/Understanding-ROS2-Topics/Understanding-ROS2-Topics.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Beginner-CLI-Tools/Understanding-ROS2-Services/Understanding-ROS2-Services.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Beginner-CLI-Tools/Understanding-ROS2-Parameters/Understanding-ROS2-Parameters.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Beginner-CLI-Tools/Understanding-ROS2-Actions/Understanding-ROS2-Actions.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Beginner-CLI-Tools/Using-Rqt-Console/Using-Rqt-Console.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Beginner-CLI-Tools/Launching-Multiple-Nodes/Launching-Multiple-Nodes.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Beginner-CLI-Tools/Recording-And-Playing-Back-Data/Recording-And-Playing-Back-Data.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Beginner-Client-Libraries.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Beginner-Client-Libraries/Colcon-Tutorial.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Beginner-Client-Libraries/Creating-A-Workspace/Creating-A-Workspace.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Beginner-Client-Libraries/Creating-Your-First-ROS2-Package.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Beginner-Client-Libraries/Writing-A-Simple-Cpp-Publisher-And-Subscriber.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Beginner-Client-Libraries/Writing-A-Simple-Py-Publisher-And-Subscriber.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Beginner-Client-Libraries/Writing-A-Simple-Cpp-Service-And-Client.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Beginner-Client-Libraries/Writing-A-Simple-Py-Service-And-Client.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Beginner-Client-Libraries/Custom-ROS2-Interfaces.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Beginner-Client-Libraries/Single-Package-Define-And-Use-Interface.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Beginner-Client-Libraries/Using-Parameters-In-A-Class-CPP.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Beginner-Client-Libraries/Using-Parameters-In-A-Class-Python.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Beginner-Client-Libraries/Getting-Started-With-Ros2doctor.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Beginner-Client-Libraries/Pluginlib.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Intermediate.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Intermediate/Rosdep.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Intermediate/Creating-an-Action.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Intermediate/Writing-an-Action-Server-Client/Cpp.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Intermediate/Writing-an-Action-Server-Client/Py.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Intermediate/Composition.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Intermediate/Monitoring-For-Parameter-Changes-CPP.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Intermediate/Launch/Launch-Main.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Intermediate/Launch/Creating-Launch-Files.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Intermediate/Launch/Launch-system.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Intermediate/Launch/Using-Substitutions.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Intermediate/Launch/Using-Event-Handlers.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Intermediate/Launch/Using-ROS2-Launch-For-Large-Projects.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Intermediate/Tf2/Tf2-Main.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Intermediate/Tf2/Introduction-To-Tf2.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Intermediate/Tf2/Writing-A-Tf2-Static-Broadcaster-Py.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Intermediate/Tf2/Writing-A-Tf2-Static-Broadcaster-Cpp.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Intermediate/Tf2/Writing-A-Tf2-Broadcaster-Py.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Intermediate/Tf2/Writing-A-Tf2-Broadcaster-Cpp.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Intermediate/Tf2/Writing-A-Tf2-Listener-Py.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Intermediate/Tf2/Writing-A-Tf2-Listener-Cpp.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Intermediate/Tf2/Adding-A-Frame-Py.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Intermediate/Tf2/Adding-A-Frame-Cpp.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Intermediate/Tf2/Learning-About-Tf2-And-Time-Py.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Intermediate/Tf2/Learning-About-Tf2-And-Time-Cpp.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Intermediate/Tf2/Time-Travel-With-Tf2-Py.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Intermediate/Tf2/Time-Travel-With-Tf2-Cpp.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Intermediate/Tf2/Debugging-Tf2-Problems.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Intermediate/Tf2/Quaternion-Fundamentals.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Intermediate/Tf2/Using-Stamped-Datatypes-With-Tf2-Ros-MessageFilter.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Intermediate/Testing/Testing-Main.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Intermediate/Testing/CLI.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Intermediate/Testing/Python.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Intermediate/URDF/URDF-Main.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Intermediate/URDF/Building-a-Visual-Robot-Model-with-URDF-from-Scratch.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Intermediate/URDF/Building-a-Movable-Robot-Model-with-URDF.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Intermediate/URDF/Adding-Physical-and-Collision-Properties-to-a-URDF-Model.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Intermediate/URDF/Using-Xacro-to-Clean-Up-a-URDF-File.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Intermediate/URDF/Using-URDF-with-Robot-State-Publisher.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Advanced.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Advanced/Topic-Statistics-Tutorial/Topic-Statistics-Tutorial.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Advanced/Discovery-Server/Discovery-Server.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Advanced/Allocator-Template-Tutorial.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Advanced/FastDDS-Configuration.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Advanced/Recording-A-Bag-From-Your-Own-Node-CPP.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Advanced/Recording-A-Bag-From-Your-Own-Node-Py.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Advanced/Simulators/Simulation-Main.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Advanced/Simulators/Webots.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Advanced/Simulators/Ignition.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Demos.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Demos/Quality-of-Service.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Demos/Managed-Nodes.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Demos/Intra-Process-Communication.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Demos/Rosbag-with-ROS1-Bridge.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Demos/Real-Time-Programming.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Demos/dummy-robot-demo.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Demos/Logging-and-logger-configuration.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Miscellaneous.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Miscellaneous/Deploying-ROS-2-on-IBM-Cloud.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Miscellaneous/Eclipse-Oxygen-with-ROS-2-and-rviz2.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Miscellaneous/Building-Realtime-rt_preempt-kernel-for-ROS-2.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Tutorials/Miscellaneous/Building-ROS2-Package-with-eclipse-2021-06.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/How-To-Guides.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/How-To-Guides/Installation-Troubleshooting.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/How-To-Guides/Developing-a-ROS-2-Package.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/How-To-Guides/Ament-CMake-Documentation.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/How-To-Guides/Ament-CMake-Python-Documentation.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/How-To-Guides/Launch-files-migration-guide.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/How-To-Guides/Launch-file-different-formats.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/How-To-Guides/Launching-composable-nodes.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/How-To-Guides/Parameters-YAML-files-migration-guide.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/How-To-Guides/Node-arguments.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/How-To-Guides/Sync-Vs-Async.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/How-To-Guides/DDS-tuning.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/How-To-Guides/Overriding-QoS-Policies-For-Recording-And-Playback.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/How-To-Guides/Working-with-multiple-RMW-implementations.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/How-To-Guides/Cross-compilation.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/How-To-Guides/Releasing/Releasing-a-Package.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/How-To-Guides/Releasing/First-Time-Release.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/How-To-Guides/Releasing/Subsequent-Releases.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/How-To-Guides/Releasing/Release-Team-Repository.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/How-To-Guides/Releasing/Release-Track.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/How-To-Guides/Using-Python-Packages.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/How-To-Guides/RQt-Port-Plugin-Windows.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/How-To-Guides/Run-2-nodes-in-single-or-separate-docker-containers.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/How-To-Guides/Visualizing-ROS-2-Data-With-Foxglove-Studio.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/How-To-Guides/Package-maintainer-guide.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/How-To-Guides/Building-a-Custom-Debian-Package.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/How-To-Guides/Building-ROS-2-with-Tracing-Instrumentation.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/How-To-Guides/Topics-Services-Actions.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/How-To-Guides/Using-Variants.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/How-To-Guides/Using-ros2-param.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/How-To-Guides/Installing-on-Raspberry-Pi.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/How-To-Guides/Using-callback-groups.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/How-To-Guides/RQt-Source-Install.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/How-To-Guides/RQt-Source-Install-MacOS.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/How-To-Guides/RQt-Source-Install-Windows10.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Concepts.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Concepts/About-Domain-ID.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Concepts/About-Different-Middleware-Vendors.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Concepts/About-Logging.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Concepts/About-Quality-of-Service-Settings.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Concepts/About-ROS-2-Client-Libraries.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Concepts/About-ROS-Interfaces.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Concepts/About-ROS-2-Parameters.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Concepts/About-Executors.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Concepts/About-Topic-Statistics.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Concepts/About-Command-Line-Tools.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Concepts/About-RQt.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Concepts/About-Composition.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Concepts/About-Catment.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Concepts/About-Cross-Compilation.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Concepts/About-Tf2.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Concepts/About-Build-System.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Concepts/About-Internal-Interfaces.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Concepts/About-Middleware-Implementations.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Contact.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/The-ROS2-Project.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/The-ROS2-Project/Contributing.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/The-ROS2-Project/Contributing/Developer-Guide.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/The-ROS2-Project/Contributing/Code-Style-Language-Versions.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/The-ROS2-Project/Contributing/Quality-Guide.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/The-ROS2-Project/Contributing/Migration-Guide.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/The-ROS2-Project/Contributing/Migration-Guide-Python.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/The-ROS2-Project/Contributing/Build-Farms.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/The-ROS2-Project/Contributing/Windows-Tips-and-Tricks.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/The-ROS2-Project/Contributing/Contributing-To-ROS-2-Documentation.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/The-ROS2-Project/Features.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/The-ROS2-Project/Feature-Ideas.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/The-ROS2-Project/Roadmap.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/The-ROS2-Project/ROSCon-Content.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/The-ROS2-Project/Governance.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/The-ROS2-Project/Governance/ROS2-TSC-Charter.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/The-ROS2-Project/Governance/ROS2-TSC-Intake-process.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/The-ROS2-Project/Governance/How-To-Start-A-Community-Working-Group.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/The-ROS2-Project/Marketing.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Related-Projects.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Related-Projects/Intel-ROS2-Projects.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Related-Projects/Nvidia-ROS2-Projects.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/galactic/Glossary.html
# Saved data into MongoDB for URL: https://docs.nav2.org/development_guides/index.html
# Saved data into MongoDB for URL: https://docs.nav2.org/development_guides/build_docs/index.html
# Saved data into MongoDB for URL: https://docs.nav2.org/development_guides/build_docs/index.html#install
# Saved data into MongoDB for URL: https://docs.nav2.org/development_guides/build_docs/index.html#for-iron-and-older
# Saved data into MongoDB for URL: https://docs.nav2.org/development_guides/build_docs/index.html#for-jazzy-and-newer
# Saved data into MongoDB for URL: https://docs.nav2.org/development_guides/build_docs/index.html#build
# Saved data into MongoDB for URL: https://docs.nav2.org/development_guides/build_docs/index.html#released-distribution-binaries
# Saved data into MongoDB for URL: https://docs.nav2.org/development_guides/build_docs/index.html#rolling-development-source
# Saved data into MongoDB for URL: https://docs.nav2.org/development_guides/build_docs/index.html#docker-container-images
# Saved data into MongoDB for URL: https://docs.nav2.org/development_guides/build_docs/index.html#generate-doxygen
# Saved data into MongoDB for URL: https://docs.nav2.org/development_guides/build_docs/index.html#help
# Saved data into MongoDB for URL: https://docs.nav2.org/development_guides/build_docs/build_troubleshooting_guide.html
# Saved data into MongoDB for URL: https://docs.nav2.org/development_guides/devcontainer_docs/index.html
# Saved data into MongoDB for URL: https://docs.nav2.org/development_guides/devcontainer_docs/devcontainer_guide.html
# Saved data into MongoDB for URL: https://docs.nav2.org/development_guides/devcontainer_docs/devcontainer_guide.html#creating-dev-containers
# Saved data into MongoDB for URL: https://docs.nav2.org/development_guides/devcontainer_docs/devcontainer_guide.html#using-dev-containers
# Saved data into MongoDB for URL: https://docs.nav2.org/development_guides/devcontainer_docs/index.html#what-why-how
# Saved data into MongoDB for URL: https://docs.nav2.org/development_guides/devcontainer_docs/index.html#what-is-a-dev-container
# Saved data into MongoDB for URL: https://docs.nav2.org/development_guides/devcontainer_docs/index.html#why-use-a-dev-container
# Saved data into MongoDB for URL: https://docs.nav2.org/development_guides/devcontainer_docs/index.html#how-do-dev-containers-work
# Saved data into MongoDB for URL: https://docs.nav2.org/development_guides/devcontainer_docs/index.html#prerequisites
# Saved data into MongoDB for URL: https://docs.nav2.org/development_guides/devcontainer_docs/index.html#getting-started
# Saved data into MongoDB for URL: https://docs.nav2.org/development_guides/devcontainer_docs/index.html#security
# Saved data into MongoDB for URL: https://docs.nav2.org/development_guides/involvement_docs/index.html
# Saved data into MongoDB for URL: https://docs.nav2.org/development_guides/involvement_docs/index.html#id1
# Saved data into MongoDB for URL: https://docs.nav2.org/development_guides/involvement_docs/index.html#process
# Saved data into MongoDB for URL: https://docs.nav2.org/development_guides/involvement_docs/index.html#licensing
# Saved data into MongoDB for URL: https://docs.nav2.org/development_guides/involvement_docs/index.html#developer-certification-of-origin-dco
# Saved data into MongoDB for URL: https://docs.nav2.org/concepts/index.html
# Saved data into MongoDB for URL: https://docs.nav2.org/concepts/index.html#ros-2
# Saved data into MongoDB for URL: https://docs.nav2.org/concepts/index.html#action-server
# Saved data into MongoDB for URL: https://docs.nav2.org/concepts/index.html#lifecycle-nodes-and-bond
# Saved data into MongoDB for URL: https://docs.nav2.org/concepts/index.html#behavior-trees
# Saved data into MongoDB for URL: https://docs.nav2.org/concepts/index.html#navigation-servers
# Saved data into MongoDB for URL: https://docs.nav2.org/concepts/index.html#planner-controller-smoother-and-recovery-servers
# Saved data into MongoDB for URL: https://docs.nav2.org/concepts/index.html#planners
# Saved data into MongoDB for URL: https://docs.nav2.org/concepts/index.html#controllers
# Saved data into MongoDB for URL: https://docs.nav2.org/concepts/index.html#behaviors
# Saved data into MongoDB for URL: https://docs.nav2.org/concepts/index.html#smoothers
# Saved data into MongoDB for URL: https://docs.nav2.org/concepts/index.html#robot-footprints
# Saved data into MongoDB for URL: https://docs.nav2.org/concepts/index.html#waypoint-following
# Saved data into MongoDB for URL: https://docs.nav2.org/concepts/index.html#state-estimation
# Saved data into MongoDB for URL: https://docs.nav2.org/concepts/index.html#standards
# Saved data into MongoDB for URL: https://docs.nav2.org/concepts/index.html#global-positioning-localization-and-slam
# Saved data into MongoDB for URL: https://docs.nav2.org/concepts/index.html#odometry
# Saved data into MongoDB for URL: https://docs.nav2.org/concepts/index.html#environmental-representation
# Saved data into MongoDB for URL: https://docs.nav2.org/concepts/index.html#costmaps-and-layers
# Saved data into MongoDB for URL: https://docs.nav2.org/concepts/index.html#costmap-filters
# Saved data into MongoDB for URL: https://docs.nav2.org/concepts/index.html#other-forms
# Saved data into MongoDB for URL: https://docs.nav2.org/concepts/index.html#nav2-academic-overview
# Saved data into MongoDB for URL: https://docs.nav2.org/setup_guides/index.html
# Saved data into MongoDB for URL: https://docs.nav2.org/setup_guides/transformation/setup_transforms.html
# Saved data into MongoDB for URL: https://docs.nav2.org/setup_guides/transformation/setup_transforms.html#transforms-introduction
# Saved data into MongoDB for URL: https://docs.nav2.org/setup_guides/transformation/setup_transforms.html#static-transform-publisher-demo
# Saved data into MongoDB for URL: https://docs.nav2.org/setup_guides/transformation/setup_transforms.html#transforms-in-navigation2
# Saved data into MongoDB for URL: https://docs.nav2.org/setup_guides/transformation/setup_transforms.html#conclusion
# Saved data into MongoDB for URL: https://docs.nav2.org/setup_guides/urdf/setup_urdf.html
# Saved data into MongoDB for URL: https://docs.nav2.org/setup_guides/urdf/setup_urdf.html#urdf-and-the-robot-state-publisher
# Saved data into MongoDB for URL: https://docs.nav2.org/setup_guides/urdf/setup_urdf.html#setting-up-the-environment
# Saved data into MongoDB for URL: https://docs.nav2.org/setup_guides/urdf/setup_urdf.html#writing-the-urdf
# Saved data into MongoDB for URL: https://docs.nav2.org/setup_guides/urdf/setup_urdf.html#build-and-launch
# Saved data into MongoDB for URL: https://docs.nav2.org/setup_guides/urdf/setup_urdf.html#visualization-using-rviz
# Saved data into MongoDB for URL: https://docs.nav2.org/setup_guides/urdf/setup_urdf.html#adding-physical-properties
# Saved data into MongoDB for URL: https://docs.nav2.org/setup_guides/urdf/setup_urdf.html#conclusion
# Saved data into MongoDB for URL: https://docs.nav2.org/setup_guides/odom/setup_odom.html
# Saved data into MongoDB for URL: https://docs.nav2.org/setup_guides/odom/setup_odom.html#odometry-introduction
# Saved data into MongoDB for URL: https://docs.nav2.org/setup_guides/odom/setup_odom.html#setting-up-odometry-on-your-robot
# Saved data into MongoDB for URL: https://docs.nav2.org/setup_guides/odom/setup_odom.html#simulating-an-odometry-system-using-gazebo
# Saved data into MongoDB for URL: https://docs.nav2.org/setup_guides/odom/setup_odom.html#setup-and-prerequisites
# Saved data into MongoDB for URL: https://docs.nav2.org/setup_guides/odom/setup_odom.html#adding-gazebo-plugins-to-a-urdf
# Saved data into MongoDB for URL: https://docs.nav2.org/setup_guides/odom/setup_odom.html#launch-and-build-files
# Saved data into MongoDB for URL: https://docs.nav2.org/setup_guides/odom/setup_odom.html#build-run-and-verification
# Saved data into MongoDB for URL: https://docs.nav2.org/setup_guides/odom/setup_odom.html#robot-localization-demo
# Saved data into MongoDB for URL: https://docs.nav2.org/setup_guides/odom/setup_odom.html#configuring-robot-localization
# Saved data into MongoDB for URL: https://docs.nav2.org/setup_guides/odom/setup_odom.html#id3
# Saved data into MongoDB for URL: https://docs.nav2.org/setup_guides/odom/setup_odom.html#id4
# Saved data into MongoDB for URL: https://docs.nav2.org/setup_guides/odom/setup_odom.html#conclusion
# Saved data into MongoDB for URL: https://docs.nav2.org/setup_guides/sensors/setup_sensors.html
# Saved data into MongoDB for URL: https://docs.nav2.org/setup_guides/sensors/setup_sensors.html#sensor-introduction
# Saved data into MongoDB for URL: https://docs.nav2.org/setup_guides/sensors/setup_sensors.html#common-sensor-messages
# Saved data into MongoDB for URL: https://docs.nav2.org/setup_guides/sensors/setup_sensors.html#simulating-sensors-using-gazebo
# Saved data into MongoDB for URL: https://docs.nav2.org/setup_guides/sensors/setup_sensors.html#adding-gazebo-plugins-to-a-urdf
# Saved data into MongoDB for URL: https://docs.nav2.org/setup_guides/sensors/setup_sensors.html#launch-and-build-files
# Saved data into MongoDB for URL: https://docs.nav2.org/setup_guides/sensors/setup_sensors.html#build-run-and-verification
# Saved data into MongoDB for URL: https://docs.nav2.org/setup_guides/sensors/setup_sensors.html#mapping-and-localization
# Saved data into MongoDB for URL: https://docs.nav2.org/setup_guides/sensors/setup_sensors.html#costmap-2d
# Saved data into MongoDB for URL: https://docs.nav2.org/setup_guides/sensors/setup_sensors.html#configuring-nav2-costmap-2d
# Saved data into MongoDB for URL: https://docs.nav2.org/setup_guides/sensors/setup_sensors.html#id2
# Saved data into MongoDB for URL: https://docs.nav2.org/setup_guides/sensors/setup_sensors.html#conclusion
# Saved data into MongoDB for URL: https://docs.nav2.org/setup_guides/footprint/setup_footprint.html
# Saved data into MongoDB for URL: https://docs.nav2.org/setup_guides/footprint/setup_footprint.html#footprint-introduction
# Saved data into MongoDB for URL: https://docs.nav2.org/setup_guides/footprint/setup_footprint.html#configuring-the-robot-s-footprint
# Saved data into MongoDB for URL: https://docs.nav2.org/setup_guides/footprint/setup_footprint.html#build-run-and-verification
# Saved data into MongoDB for URL: https://docs.nav2.org/setup_guides/footprint/setup_footprint.html#visualizing-footprint-in-rviz
# Saved data into MongoDB for URL: https://docs.nav2.org/setup_guides/footprint/setup_footprint.html#conclusion
# Saved data into MongoDB for URL: https://docs.nav2.org/setup_guides/algorithm/select_algorithm.html
# Saved data into MongoDB for URL: https://docs.nav2.org/setup_guides/algorithm/select_algorithm.html#planner-and-controller-servers
# Saved data into MongoDB for URL: https://docs.nav2.org/setup_guides/algorithm/select_algorithm.html#selecting-the-algorithm-plugins
# Saved data into MongoDB for URL: https://docs.nav2.org/setup_guides/algorithm/select_algorithm.html#planner-server
# Saved data into MongoDB for URL: https://docs.nav2.org/setup_guides/algorithm/select_algorithm.html#controller-server
# Saved data into MongoDB for URL: https://docs.nav2.org/setup_guides/algorithm/select_algorithm.html#conclusion
# Saved data into MongoDB for URL: https://docs.nav2.org/about/robots.html
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/index.html
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/navigation2_on_real_turtlebot3.html
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/navigation2_on_real_turtlebot3.html#overview
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/navigation2_on_real_turtlebot3.html#requirements
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/navigation2_on_real_turtlebot3.html#tutorial-steps
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/navigation2_on_real_turtlebot3.html#setup-your-environment-variables
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/navigation2_on_real_turtlebot3.html#launch-turtlebot-3
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/navigation2_on_real_turtlebot3.html#launch-nav2
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/navigation2_on_real_turtlebot3.html#launch-rviz
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/navigation2_on_real_turtlebot3.html#initialize-the-location-of-turtlebot-3
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/navigation2_on_real_turtlebot3.html#send-a-goal-pose
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/navigation2_with_slam.html
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/navigation2_with_slam.html#overview
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/navigation2_with_slam.html#requirements
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/navigation2_with_slam.html#tutorial-steps
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/navigation2_with_slam.html#launch-robot-interfaces
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/navigation2_with_slam.html#launch-navigation2
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/navigation2_with_slam.html#launch-slam
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/navigation2_with_slam.html#working-with-slam
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/navigation2_with_slam.html#getting-started-simplification
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/navigation2_with_stvl.html
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/navigation2_with_stvl.html#overview
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/navigation2_with_stvl.html#costmap2d-and-stvl
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/navigation2_with_stvl.html#tutorial-steps
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/navigation2_with_stvl.html#setup
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/navigation2_with_stvl.html#install-stvl
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/navigation2_with_stvl.html#modify-navigation2-parameter
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/navigation2_with_stvl.html#launch-navigation2
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/navigation2_with_stvl.html#rviz
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/navigation2_with_gps.html
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/navigation2_with_gps.html#overview
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/navigation2_with_gps.html#requirements
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/navigation2_with_gps.html#gps-localization-overview
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/navigation2_with_gps.html#tutorial-steps
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/navigation2_with_gps.html#setup-gazebo-world
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/navigation2_with_gps.html#setup-gps-localization-system
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/navigation2_with_gps.html#setup-navigation-system
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/navigation2_with_gps.html#interactive-gps-waypoint-follower
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/navigation2_with_gps.html#logged-gps-waypoint-follower-waypoint-logging
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/navigation2_with_gps.html#conclusion
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/using_groot.html
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/using_groot.html#overview
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/using_groot.html#visualize-behavior-trees
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/using_groot.html#edit-behavior-trees
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/using_groot.html#adding-a-custom-node
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/integrating_vio.html
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/integrating_vio.html#overview
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/integrating_vio.html#setting-up-the-zed-x-camera
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/integrating_vio.html#setting-up-zed-ros
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/integrating_vio.html#fusing-vio-into-local-state-estimate
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/integrating_vio.html#fusing-vslam-into-global-state-estimate
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/integrating_vio.html#testing-it-out
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/navigation2_dynamic_point_following.html
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/navigation2_dynamic_point_following.html#overview
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/navigation2_dynamic_point_following.html#tutorial-steps
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/navigation2_dynamic_point_following.html#create-the-behavior-tree
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/navigation2_dynamic_point_following.html#setup-rviz-clicked-point
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/navigation2_dynamic_point_following.html#run-dynamic-object-following-in-nav2-simulation
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/navigation2_with_keepout_filter.html
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/navigation2_with_keepout_filter.html#overview
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/navigation2_with_keepout_filter.html#requirements
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/navigation2_with_keepout_filter.html#tutorial-steps
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/navigation2_with_keepout_filter.html#prepare-filter-mask
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/navigation2_with_keepout_filter.html#configure-costmap-filter-info-publisher-server
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/navigation2_with_keepout_filter.html#enable-keepout-filter
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/navigation2_with_keepout_filter.html#run-nav2-stack
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/navigation2_with_speed_filter.html
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/navigation2_with_speed_filter.html#overview
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/navigation2_with_speed_filter.html#requirements
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/navigation2_with_speed_filter.html#tutorial-steps
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/navigation2_with_speed_filter.html#prepare-filter-mask
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/navigation2_with_speed_filter.html#configure-costmap-filter-info-publisher-server
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/navigation2_with_speed_filter.html#enable-speed-filter
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/navigation2_with_speed_filter.html#run-nav2-stack
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/using_docking.html
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/using_docking.html#overview
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/using_docking.html#requirements
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/using_docking.html#chargingdock-plugins
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/using_docking.html#dock-database
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/using_docking.html#configuring-docking-server
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/using_docking.html#adding-docking-server-to-launch
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/using_docking.html#docking-action-api
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/using_docking.html#putting-it-all-together
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/using_shim_controller.html
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/using_shim_controller.html#overview
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/using_shim_controller.html#what-is-the-rotation-shim-controller
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/using_shim_controller.html#configuring-rotation-shim-controller
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/using_shim_controller.html#configuring-primary-controller
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/using_shim_controller.html#demo-execution
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/adding_smoother.html
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/adding_smoother.html#overview
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/adding_smoother.html#requirements
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/adding_smoother.html#tutorial-steps
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/adding_smoother.html#familiarization-with-the-smoother-bt-node
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/adding_smoother.html#specifying-a-smoother-plugin
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/adding_smoother.html#modifying-your-bt-xml
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/using_collision_monitor.html
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/using_collision_monitor.html#overview
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/using_collision_monitor.html#requirements
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/using_collision_monitor.html#configuring-collision-monitor
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/using_collision_monitor.html#configuring-collision-monitor-with-velocitypolygon
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/using_collision_monitor.html#preparing-nav2-stack
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/using_collision_monitor.html#demo-execution
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/adding_a_nav2_task_server.html
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/adding_a_nav2_task_server.html#lifecycle-nodes
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/adding_a_nav2_task_server.html#composition
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/adding_a_nav2_task_server.html#error-codes
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/adding_a_nav2_task_server.html#conclusion
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/filtering_of_noise-induced_obstacles.html
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/filtering_of_noise-induced_obstacles.html#overview
# Saved data into MongoDB for URL: https://docs.nav2.org/tutorials/docs/filtering_of_noise-induced_obstacles.html#requirements
# ...
# Saved data into MongoDB for URL: https://docs.ros.org/en/kinetic/api/moveit_tutorials/html/doc/kinematics_configuration/kinematics_configuration_tutorial.html#position-only-ik
# Saved data into MongoDB for URL: https://docs.ros.org/en/kinetic/api/moveit_tutorials/html/doc/fake_controller_manager/fake_controller_manager_tutorial.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/kinetic/api/moveit_tutorials/html/doc/fake_controller_manager/fake_controller_manager_tutorial.html#yaml-file-examples
# Saved data into MongoDB for URL: https://docs.ros.org/en/kinetic/api/moveit_tutorials/html/doc/custom_constraint_samplers/custom_constraint_samplers_tutorial.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/kinetic/api/moveit_tutorials/html/doc/custom_constraint_samplers/custom_constraint_samplers_tutorial.html#overview
# Saved data into MongoDB for URL: https://docs.ros.org/en/kinetic/api/moveit_tutorials/html/doc/custom_constraint_samplers/custom_constraint_samplers_tutorial.html#getting-started
# Saved data into MongoDB for URL: https://docs.ros.org/en/kinetic/api/moveit_tutorials/html/doc/custom_constraint_samplers/custom_constraint_samplers_tutorial.html#creating-a-constraint-sampler
# Saved data into MongoDB for URL: https://docs.ros.org/en/kinetic/api/moveit_tutorials/html/doc/ompl_interface/ompl_interface_tutorial.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/kinetic/api/moveit_tutorials/html/doc/ompl_interface/ompl_interface_tutorial.html#ompl-settings
# Saved data into MongoDB for URL: https://docs.ros.org/en/kinetic/api/moveit_tutorials/html/doc/ompl_interface/ompl_interface_tutorial.html#longest-valid-segment-fraction
# Saved data into MongoDB for URL: https://docs.ros.org/en/kinetic/api/moveit_tutorials/html/doc/ompl_interface/ompl_interface_tutorial.html#projection-evaluator
# Saved data into MongoDB for URL: https://docs.ros.org/en/kinetic/api/moveit_tutorials/html/doc/ompl_interface/ompl_interface_tutorial.html#enforce-planning-in-joint-space
# Saved data into MongoDB for URL: https://docs.ros.org/en/kinetic/api/moveit_tutorials/html/doc/ompl_interface/ompl_interface_tutorial.html#other-settings
# Saved data into MongoDB for URL: https://docs.ros.org/en/kinetic/api/moveit_tutorials/html/doc/ompl_interface/ompl_interface_tutorial.html#ompl-optimization-objectives
# Saved data into MongoDB for URL: https://docs.ros.org/en/kinetic/api/moveit_tutorials/html/doc/chomp_planner/chomp_planner_tutorial.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/kinetic/api/moveit_tutorials/html/doc/chomp_planner/chomp_planner_tutorial.html#getting-started
# Saved data into MongoDB for URL: https://docs.ros.org/en/kinetic/api/moveit_tutorials/html/doc/chomp_planner/chomp_planner_tutorial.html#prerequisites
# Saved data into MongoDB for URL: https://docs.ros.org/en/kinetic/api/moveit_tutorials/html/doc/chomp_planner/chomp_planner_tutorial.html#installing-moveit-from-source
# Saved data into MongoDB for URL: https://docs.ros.org/en/kinetic/api/moveit_tutorials/html/doc/chomp_planner/chomp_planner_tutorial.html#using-chomp-with-your-robot
# Saved data into MongoDB for URL: https://docs.ros.org/en/kinetic/api/moveit_tutorials/html/doc/chomp_planner/chomp_planner_tutorial.html#running-the-demo
# Saved data into MongoDB for URL: https://docs.ros.org/en/kinetic/api/moveit_tutorials/html/doc/chomp_planner/chomp_planner_tutorial.html#running-chomp-with-obstacles-in-the-scene
# Saved data into MongoDB for URL: https://docs.ros.org/en/kinetic/api/moveit_tutorials/html/doc/chomp_planner/chomp_planner_tutorial.html#tweaking-some-of-the-parameters-for-chomp
# Saved data into MongoDB for URL: https://docs.ros.org/en/kinetic/api/moveit_tutorials/html/doc/chomp_planner/chomp_planner_tutorial.html#difference-between-plans-obtained-by-chomp-and-ompl
# Saved data into MongoDB for URL: https://docs.ros.org/en/kinetic/api/moveit_tutorials/html/doc/chomp_planner/chomp_planner_tutorial.html#using-ompl-as-a-pre-processor-for-chomp
# Saved data into MongoDB for URL: https://docs.ros.org/en/kinetic/api/moveit_tutorials/html/doc/stomp_planner/stomp_planner_tutorial.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/kinetic/api/moveit_tutorials/html/doc/stomp_planner/stomp_planner_tutorial.html#getting-started
# Saved data into MongoDB for URL: https://docs.ros.org/en/kinetic/api/moveit_tutorials/html/doc/stomp_planner/stomp_planner_tutorial.html#prerequisites
# Saved data into MongoDB for URL: https://docs.ros.org/en/kinetic/api/moveit_tutorials/html/doc/stomp_planner/stomp_planner_tutorial.html#installing-moveit-from-source
# Saved data into MongoDB for URL: https://docs.ros.org/en/kinetic/api/moveit_tutorials/html/doc/stomp_planner/stomp_planner_tutorial.html#using-stomp-with-your-robot
# Saved data into MongoDB for URL: https://docs.ros.org/en/kinetic/api/moveit_tutorials/html/doc/stomp_planner/stomp_planner_tutorial.html#running-the-demo
# Saved data into MongoDB for URL: https://docs.ros.org/en/kinetic/api/moveit_tutorials/html/doc/stomp_planner/stomp_planner_tutorial.html#running-stomp-with-obstacles-in-the-scene
# Saved data into MongoDB for URL: https://docs.ros.org/en/kinetic/api/moveit_tutorials/html/doc/stomp_planner/stomp_planner_tutorial.html#tweaking-some-of-the-parameters-for-stomp
# Saved data into MongoDB for URL: https://docs.ros.org/en/kinetic/api/moveit_tutorials/html/doc/stomp_planner/stomp_planner_tutorial.html#difference-between-plans-obtained-by-stomp-chomp-and-ompl
# Saved data into MongoDB for URL: https://docs.ros.org/en/kinetic/api/moveit_tutorials/html/doc/stomp_planner/stomp_planner_tutorial.html#running-stomp-unit-tests
# Saved data into MongoDB for URL: https://docs.ros.org/en/kinetic/api/moveit_tutorials/html/doc/planning_adapters/planning_adapters_tutorial.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/kinetic/api/moveit_tutorials/html/doc/planning_adapters/planning_adapters_tutorial.html#getting-started
# Saved data into MongoDB for URL: https://docs.ros.org/en/kinetic/api/moveit_tutorials/html/doc/planning_adapters/planning_adapters_tutorial.html#prerequisites
# Saved data into MongoDB for URL: https://docs.ros.org/en/kinetic/api/moveit_tutorials/html/doc/planning_adapters/planning_adapters_tutorial.html#installing-moveit-from-source
# Saved data into MongoDB for URL: https://docs.ros.org/en/kinetic/api/moveit_tutorials/html/doc/planning_adapters/planning_adapters_tutorial.html#using-planning-request-adapter-with-your-motion-planner
# Saved data into MongoDB for URL: https://docs.ros.org/en/kinetic/api/moveit_tutorials/html/doc/planning_adapters/planning_adapters_tutorial.html#running-ompl-as-a-pre-processor-for-chomp
# Saved data into MongoDB for URL: https://docs.ros.org/en/kinetic/api/moveit_tutorials/html/doc/planning_adapters/planning_adapters_tutorial.html#running-chomp-as-a-post-processor-for-stomp
# Saved data into MongoDB for URL: https://docs.ros.org/en/kinetic/api/moveit_tutorials/html/doc/planning_adapters/planning_adapters_tutorial.html#running-ompl-as-a-pre-processor-for-stomp
# Saved data into MongoDB for URL: https://docs.ros.org/en/kinetic/api/moveit_tutorials/html/doc/planning_adapters/planning_adapters_tutorial.html#running-stomp-as-a-post-processor-for-chomp
# Saved data into MongoDB for URL: https://docs.ros.org/en/kinetic/api/moveit_tutorials/html/doc/planning_adapters/planning_adapters_tutorial.html#planning-insights-for-different-motion-planners-and-planners-with-planning-adapters
# Saved data into MongoDB for URL: https://docs.ros.org/en/kinetic/api/moveit_tutorials/html/doc/joystick_control_teleoperation/joystick_control_teleoperation_tutorial.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/kinetic/api/moveit_tutorials/html/doc/joystick_control_teleoperation/joystick_control_teleoperation_tutorial.html#getting-started
# Saved data into MongoDB for URL: https://docs.ros.org/en/kinetic/api/moveit_tutorials/html/doc/joystick_control_teleoperation/joystick_control_teleoperation_tutorial.html#running-the-code
# Saved data into MongoDB for URL: https://docs.ros.org/en/kinetic/api/moveit_tutorials/html/doc/joystick_control_teleoperation/joystick_control_teleoperation_tutorial.html#joystick-command-mappings
# Saved data into MongoDB for URL: https://docs.ros.org/en/kinetic/api/moveit_tutorials/html/doc/joystick_control_teleoperation/joystick_control_teleoperation_tutorial.html#debugging
# Saved data into MongoDB for URL: https://docs.ros.org/en/kinetic/api/moveit_tutorials/html/doc/benchmarking/benchmarking_tutorial.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/kinetic/api/moveit_tutorials/html/doc/benchmarking/benchmarking_tutorial.html#getting-started
# Saved data into MongoDB for URL: https://docs.ros.org/en/kinetic/api/moveit_tutorials/html/doc/benchmarking/benchmarking_tutorial.html#example
# Saved data into MongoDB for URL: https://docs.ros.org/en/kinetic/api/moveit_tutorials/html/doc/benchmarking/benchmarking_tutorial.html#viewing-results
# Saved data into MongoDB for URL: https://docs.ros.org/en/kinetic/api/moveit_tutorials/html/doc/benchmarking/benchmarking_tutorial.html#parameters-of-the-benchmarkoptions-class
# Saved data into MongoDB for URL: https://docs.ros.org/en/kinetic/api/moveit_tutorials/html/doc/benchmarking/benchmarking_tutorial.html#parameters-of-the-benchmarkexecutor-class
# Saved data into MongoDB for URL: https://docs.ros.org/en/kinetic/api/moveit_tutorials/html/doc/benchmarking/benchmarking_tutorial.html#benchmarking-of-different-motion-planners-chomp-stomp-and-ompl
# Saved data into MongoDB for URL: https://docs.ros.org/en/kinetic/api/moveit_tutorials/html/doc/benchmarking/benchmarking_tutorial.html#benchmarking-in-a-scene-without-obstacles
# Saved data into MongoDB for URL: https://docs.ros.org/en/kinetic/api/moveit_tutorials/html/doc/benchmarking/benchmarking_tutorial.html#benchmarking-in-a-scene-with-obstacles
# Saved data into MongoDB for URL: https://docs.ros.org/en/kinetic/api/moveit_tutorials/html/doc/tests/tests_tutorial.html
# Saved data into MongoDB for URL: https://docs.ros.org/en/kinetic/api/moveit_tutorials/html/doc/tests/tests_tutorial.html#getting-started
# Saved data into MongoDB for URL: https://docs.ros.org/en/kinetic/api/moveit_tutorials/html/doc/tests/tests_tutorial.html#integration-test
# Saved data into MongoDB for URL: https://docs.ros.org/en/kinetic/api/moveit_tutorials/html/doc/tests/tests_tutorial.html#test-robots
# Saved data into MongoDB for URL: https://docs.ros.org/en/kinetic/api/moveit_tutorials/html/doc/tests/tests_tutorial.html#unit-tests
# Saved data into MongoDB for URL: https://gazebosim.org/docs/latest/install/
# Saved data into MongoDB for URL: https://gazebosim.org/docs/latest/install_ubuntu/
# Saved data into MongoDB for URL: https://gazebosim.org/docs/latest/install_osx/
# Saved data into MongoDB for URL: https://gazebosim.org/docs/latest/install_windows/
# Saved data into MongoDB for URL: https://gazebosim.org/docs/latest/install_ubuntu_src/
# Saved data into MongoDB for URL: https://gazebosim.org/docs/latest/install_osx_src/
# Saved data into MongoDB for URL: https://gazebosim.org/docs/latest/install_windows_src/
# Saved data into MongoDB for URL: https://gazebosim.org/docs/latest/troubleshooting/
# Saved data into MongoDB for URL: https://gazebosim.org/docs/latest/migration_from_ignition/
# Saved data into MongoDB for URL: https://gazebosim.org/docs/latest/comparison/
# Saved data into MongoDB for URL: https://gazebosim.org/docs/latest/tutorials/
# Saved data into MongoDB for URL: https://gazebosim.org/docs/latest/building_robot/
# Saved data into MongoDB for URL: https://gazebosim.org/docs/latest/moving_robot/
# Saved data into MongoDB for URL: https://gazebosim.org/docs/latest/sdf_worlds/
# Saved data into MongoDB for URL: https://gazebosim.org/docs/latest/sensors/
# Saved data into MongoDB for URL: https://gazebosim.org/docs/latest/actors/
# Saved data into MongoDB for URL: https://gazebosim.org/docs/latest/gui/
# Saved data into MongoDB for URL: https://gazebosim.org/docs/latest/manipulating_models/
# Saved data into MongoDB for URL: https://gazebosim.org/docs/latest/fuel_insert/
# Saved data into MongoDB for URL: https://gazebosim.org/docs/latest/hotkeys/
# Saved data into MongoDB for URL: https://gazebosim.org/docs/latest/spawn_urdf/
# Saved data into MongoDB for URL: https://gazebosim.org/docs/latest/ros2_overview/
# Saved data into MongoDB for URL: https://gazebosim.org/docs/latest/ros2_launch_gazebo/
# Saved data into MongoDB for URL: https://gazebosim.org/docs/latest/ros2_integration/
# Saved data into MongoDB for URL: https://gazebosim.org/docs/latest/ros2_spawn_model/
# Saved data into MongoDB for URL: https://gazebosim.org/docs/latest/ros2_interop/
# Saved data into MongoDB for URL: https://gazebosim.org/docs/latest/ros_gz_project_template_guide/
# Saved data into MongoDB for URL: https://gazebosim.org/docs/latest/ros_installation/
# Saved data into MongoDB for URL: https://gazebosim.org/docs/latest/ros2_gz_vendor_pkgs/
# Saved data into MongoDB for URL: https://gazebosim.org/docs/latest/setup_gazebo_in_ci/
# Saved data into MongoDB for URL: https://gazebosim.org/docs/latest/gazebo_classic_migration/
# Saved data into MongoDB for URL: https://gazebosim.org/docs/latest/install_gz11_side_by_side/
# Saved data into MongoDB for URL: https://gazebosim.org/docs/latest/migrating_gazebo_classic_ros2_packages/
# Saved data into MongoDB for URL: https://gazebosim.org/docs/latest/roadmap/
# Saved data into MongoDB for URL: https://gazebosim.org/docs/latest/release-features/
# Saved data into MongoDB for URL: https://gazebosim.org/docs/latest/releases/
# Saved data into MongoDB for URL: https://gazebosim.org/docs/latest/governance/
# Saved data into MongoDB for URL: https://gazebosim.org/docs/latest/development/
# Saved data into MongoDB for URL: https://gazebosim.org/docs/latest/contributing/
# Saved data into MongoDB for URL: https://gazebosim.org/docs/latest/ci/
# Saved data into MongoDB for URL: https://gazebosim.org/docs/latest/release/
# Saved data into MongoDB for URL: https://gazebosim.org/docs/latest/releasing/versioning_pre_nightly/
# Saved data into MongoDB for URL: https://gazebosim.org/docs/latest/releases-instructions/
# Saved data into MongoDB for URL: https://gazebosim.org/docs/latest/architecture/
# Saved data into MongoDB for URL: https://gazebosim.org/docs/latest/fuel/
# Saved data into MongoDB for URL: https://gazebosim.org/docs/latest/fuel_content_deletion_policy/
# Saved data into MongoDB for URL: https://gazebosim.org/docs/latest/fuel_contributing_model/
# Saved data into MongoDB for URL: https://gazebosim.org/docs/latest/fuel_contributing_world/
# Saved data into MongoDB for URL: https://gazebosim.org/docs/latest/fuel_copyright/
# Saved data into MongoDB for URL: https://gazebosim.org/docs/latest/fuel_data_policy/
# Saved data into MongoDB for URL: https://gazebosim.org/docs/latest/fuel_fair_use/
# Saved data into MongoDB for URL: https://gazebosim.org/docs/latest/library_reference_nav/
# Saved data into MongoDB for URL: https://gazebosim.org/api/cmake/4
# Saved data into MongoDB for URL: https://gazebosim.org/api/common/6
# Saved data into MongoDB for URL: https://gazebosim.org/api/fuel_tools/10
# Saved data into MongoDB for URL: https://gazebosim.org/api/gui/9
# Saved data into MongoDB for URL: https://gazebosim.org/api/launch/8
# Saved data into MongoDB for URL: https://gazebosim.org/api/math/8
# Saved data into MongoDB for URL: https://gazebosim.org/api/msgs/11
# Saved data into MongoDB for URL: https://gazebosim.org/api/physics/8
# Saved data into MongoDB for URL: https://gazebosim.org/api/plugin/3
# Saved data into MongoDB for URL: https://gazebosim.org/api/rendering/9
# Saved data into MongoDB for URL: https://gazebosim.org/api/sensors/9
# Saved data into MongoDB for URL: https://gazebosim.org/api/sim/9
# Saved data into MongoDB for URL: https://gazebosim.org/api/tools/2
# Saved data into MongoDB for URL: https://gazebosim.org/api/transport/14
# Saved data into MongoDB for URL: https://gazebosim.org/api/utils/3

# %% [markdown]
# We Create the Pipeline Controller, adding the functions as steps. Adding the parent attribute ensures that the function is called only after the parent task is completed.

# %%
# ClearML Pipeline Controller
pipeline = PipelineController(
    project="RAG System ETL Pipeline",
    name="ROS2 Media ETL",
    version="1.0",
)

# Add pipeline steps

pipeline.add_function_step(
    name="Fetch YouTube Data",
    function=fetch_youtube_data,
    execution_queue="default"
)

pipeline.add_function_step(
    name="Fetch GitHub Data",
    function=fetch_github_data,
    parents=["Fetch YouTube Data"],
    execution_queue="default"
)

pipeline.add_function_step(
    name="Fetch ROS Web Documentation",
    function=scrape_ros_docs,
    parents=["Fetch GitHub Data"],
    execution_queue="default"
)

pipeline.add_function_step(
    name="Fetch Gazebo Web Documentation",
    function=scrape_gazebo_docs,
    parents=["Fetch ROS Web Documentation"],
    execution_queue="default"
)

pipeline.add_function_step(
    name="Query Ingested URLs",
    function=query_ingested_urls,
    parents=["Fetch Gazebo Web Documentation"],
    execution_queue="default"
)
    
if __name__ == "__main__":
    pipeline.start_locally()
